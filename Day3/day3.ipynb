# %%
from collections import Counter 
nums =[2,3,4,5,5,3]
c=Counter(nums)
print(c)
print(type(c))
# Out:
# Counter({3: 2, 5: 2, 2: 1, 4: 1})
# <class 'collections.Counter'>

# %%
bDict ={}
bDict["a"] =bDict["a"]+1 #normal dictionary don't create a instance at run time
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 bDict ={}
# ----> 2 bDict["a"] =bDict["a"]+1 #normal dictionary don't create a instance at run time
#
# KeyError: 'a'

# %%
from collections import defaultdict
aDict = defaultdict(int) #it needs argumnet to know that what kind of value it is creating
aDict["a"] = aDict["a"]+1
aDict
# Out:
# defaultdict(int, {'a': 1})

# %%
from collections import deque
q=deque([1,2,3,4])
q.appendleft(0)
print(q)
q.pop() #pop from right 
print()
q.append(8) #right ma append hunxa 
q.popleft()
print(q)



print(q)
# Out:
# deque([0, 1, 2, 3, 4])
#
# deque([1, 2, 3, 8])
# deque([1, 2, 3, 8])

# %%
from collections import namedtuple
Point = namedtuple('Point','x y')
p=Point(2,3)
print(p)
# Out:
# Point(x=2, y=3)
