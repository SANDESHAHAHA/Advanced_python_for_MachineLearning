# %% [markdown]
# # Scrapping html using beautiful soup

# %%
from bs4 import BeautifulSoup

# %%
with open ('index.html','r') as f:
    doc = BeautifulSoup(f,'html.parser')
    print(doc)
    data = doc.find_all('h1')
    for val in data:
        print(val)
    dollar = doc.find_all('p')
    dol = dollar[1].text
    print(dol)
    # data = doc.find('h1')
    # print(data)
    # doc.title = "I changed the title"
    # print(doc.title)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Document</title>
# </head>
# <body>
# <h1>this is heading h1</h1>
# <h1>This is seocn heading tag </h1>
# <h2>this is heading h2</h2>
# <p style="color: green; line-height: 24px;">this is hello world </p>
# <p>the price is $9879</p>
# <a href="#">www.example.com</a>
# </body>
# </html>
# <h1>this is heading h1</h1>
# <h1>This is seocn heading tag </h1>
# the price is $9879

# %%
title = doc.title 
heading = doc.h1
anchor_tag = doc.a
print(title)
print(heading)
print(anchor_tag)
# Out:
# <title>Document</title>
# <h1>this is heading h1</h1>
# <a href="#">www.example.com</a>

# %%
import requests

# %%
url ='https://onlinekhabar.com'
response  = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.text,'html.parser')
    print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <meta content="108349739223556" property="fb:pages">
# <meta content="366639890155270" property="fb:app_id">
# <title>Online Khabar – No 1 News Portal from Nepal in Nepali. – No 1 News Portal from Nepal in Nepali.</title>
# <meta content="max-image-preview:large" name="robots"/>
# <link href="https://www.onlinekhabar.com/feed" rel="alternate" title="Online Khabar » Feed" type="application/rss+xml">
# <link href="https://www.onlinekhabar.com/comments/feed" rel="alternate" title="Online Khabar » Comments Feed" type="application/rss+xml"/>
# <link href="https://www.onlinekhabar.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.onlinekhabar.com%2F" rel="alternate" title="oEmbed (JSON)" type="application/json+oembed"/>
# ...

# %%
import pandas as pd

# %%
news=[]
for tag in soup.find_all(['h2','h3']):
    a = tag.find('a')
    if a and a.get("href"):
        title = a.get_text(strip=True)
        link = a['href']
        if title:
            news.append({
                'headline':title,
                'link':link
            })
df = pd.DataFrame(news)
df.drop_duplicates(subset='headline').reset_index(drop=True)
df.to_csv('links.csv',index=False)

# %%
# scrapping article donald trump
url='https://en.wikipedia.org/wiki/Donald_Trump'
response  = requests.get(url)
if response.status_code == 200:
    soup = BeautifulSoup(response.text,'html.parser')
    print(soup)
else :
    print(response.status_code)
# Out:
# 403

# %% [markdown]
# # Handling Large Datasets

# %%
# read chunk free memory read next chunk 
for chunk in pd.read('big_file.csv',chunk_size=10000):
    print(chunk.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 2
#       1 # read chunk free memory read next chunk
# ----> 2 for chunk in pd.read('big_file.csv',chunk_size=10000):
#       3     print(chunk.head())
#
# AttributeError: module 'pandas' has no attribute 'read'
