# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    "Roll_no":[1,2,3,4,5],
    "Name":["Ram","Shyam","","suman","sita"],
    "Gender":["M","M","F","M",""],
    "JoinDate":["2012-01-01","2012-03-05","2012-03-06","2012-03-07","2012-03-08"]
})
df.to_csv("sample_data.csv",index=False)
