# %%
from bs4 import BeautifulSoup
import json 
import pandas as pd

with open("index.html","r") as f:
    soup = BeautifulSoup(f,'html.parser')
    table = soup.find('table')
    rows = table.find_all('tr')
    data = []
    for row in rows[1:]:
        td = row.find_all('td')
        data.append([data.text for data in td])
    
    df = pd.DataFrame(data,columns=['Name','Score'])
    print(df)
# Out:
#       Name Score
# 0  Sandesh     3
# 1    Suman     2

# %%
from bs4 import BeautifulSoup
import pandas as pd

with open("index.html","r") as f:
    soup = BeautifulSoup(f,"html.parser")
    table = soup.find("table")
    rows = table.find_all("tr")
    data=[]
    for row in rows[1:]:
        td = row.find_all('td')
        data.append([data.text for data in td])
    print(data)
    df = pd.DataFrame(data,columns=['Name','Score'])
    print(df)
# Out:
# [['Sandesh', '3'], ['Suman', '2']]
#       Name Score
# 0  Sandesh     3
# 1    Suman     2
